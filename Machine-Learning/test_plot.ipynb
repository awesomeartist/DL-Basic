# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np

fig = plt.figure()
ax = Axes3D(fig)


x = np.arange(-3.0, 3.0, 0.125)
y = np.arange(-2.0, 2.0, 0.125)
X,Y = np.meshgrid(x, y)

Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2)*2
ax.plot_surface(X, Y, Z,
            rstride=1,
            cstride=1,
            cmap = plt.get_cmap('rainbow'))

ax.set_zlim(-2, 2)
plt.title("3D graph")
plt.show()
print(1+2)
# Out:
# C:\Users\liang\AppData\Local\Temp\ipykernel_15928\2574906865.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# 3

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np

fig = plt.figure()
ax = Axes3D(fig)

x = np.arange(-5.0, 5.0, 1)
y = np.arange(-5.0, 5.0, 1)
X,Y = np.meshgrid(x, y)

z = np.random.rand(100)

Z = np.array(z).reshape(10, 10)
# print(Z)
ax.plot_surface(X, Y, Z,
            rstride=1,
            cstride=1,
            cmap = plt.get_cmap('rainbow'))

ax.set_zlim(-2, 2)
plt.title("3D graph")
plt.show()
